# %%
# !pip install html5lib
# !pip install smtplib
# !pip3 install urllib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement urllib (from versions: none)
# ERROR: No matching distribution found for urllib

# %%
import pandas as pd
import numpy as np
import json
import requests
from bs4 import BeautifulSoup
import datetime

# %%
import html5lib
from urllib.request import urlopen

# %%
start = datetime.datetime.now()
print("Hora de inicio:",start.time())
# Out:
# Hora de inicio: 16:04:04.811647

# %%
url = "https://www.argenprop.com/departamento-y-casa-y-ph-y-terreno-venta-localidad-mendoza-mc"

# %%
page = requests.get(url)
cuerpo = BeautifulSoup(page.content, 'html5lib')
categories_list = cuerpo.findAll("a",{"class",""})

# %%
cuerpo
# Out:
# <!DOCTYPE html>
# <html lang="es"><head>
#     <link href="//script.hotjar.com" rel="preconnect"/>
# <link href="//static.hotjar.com" rel="preconnect"/>
# <link href="https://static1.sosiva451.com/" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://www.facebook.com" rel="preconnect"/>
# <link href="https://www.google.com" rel="preconnect"/>
# <link href="https://www.googleadservices.com" rel="preconnect"/>
# <link href="https://www.googletagmanager.com" rel="preconnect"/>
# <link href="https://www.googletagservices.com" rel="preconnect"/>
# <link href="https://static.criteo.net" rel="preconnect"/>
# <link href="https://sslwidget.criteo.com" rel="preconnect"/>
# <link href="https://analytics.trovit.com" rel="preconnect"/>
# <link href="https://cdn.ampproject.org" rel="preconnect"/>
# <link href="https://s3-us-west-2.amazonaws.com" rel="preconnect"/>
# <link href="https://pagead2.googlesyndication.com" rel="preconnect"/>
# ...

# %%
print(cuerpo.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <link href="//script.hotjar.com" rel="preconnect"/>
#   <link href="//static.hotjar.com" rel="preconnect"/>
#   <link href="https://static1.sosiva451.com/" rel="preconnect"/>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://www.facebook.com" rel="preconnect"/>
#   <link href="https://www.google.com" rel="preconnect"/>
#   <link href="https://www.googleadservices.com" rel="preconnect"/>
#   <link href="https://www.googletagmanager.com" rel="preconnect"/>
#   <link href="https://www.googletagservices.com" rel="preconnect"/>
#   <link href="https://static.criteo.net" rel="preconnect"/>
#   <link href="https://sslwidget.criteo.com" rel="preconnect"/>
#   <link href="https://analytics.trovit.com" rel="preconnect"/>
#   <link href="https://cdn.ampproject.org" rel="preconnect"/>
#   <link href="https://s3-us-west-2.amazonaws.com" rel="preconnect"/>
# ...

# %%
categories_list = cuerpo.findAll("a")
categories_list
# Out:
# [<a aria-hidden="true" href="/ver-mas-anuncios-hnpl" style="display:none;">Ver más avisos</a>,
#  <a class="header__logo" href="/">
#              <img alt="Argenprop" data-logo="true" src="/Content/images/argenprop/argenprop-logo.svg"/>
#          </a>,
#  <a data-menu-link="Emprendimientos" data-search-emprendimiento-header="" href="https://emprendimientos.argenprop.com/" id="entrepreneurship"><i class="basico1-icon-building"></i>
#  Emprendimientos</a>,
#  <a data-menu-link="Countries y Barrios Cerrados" data-search-countries-header="" href="https://countries.argenprop.com/" id="countries"><i class="basico1-icon-country"></i>
#  Countries y Barrios Cerrados</a>,
#  <a data-menu-link="Garantías de Alquiler" data-search-garantia-header="" href="/Garantias-Alquiler" id="garantias"><i class="basico1-icon-calculator"></i>
#  Garantías de Alquiler</a>,
#  <a data-menu-link="Noticias" href="/Noticias" id="noticias"><i class="basico1-icon-news"></i>
#  Noticias</a>,
# ...

# %%
categories_list
# Out:
# []

# %%
quotes=[]  # a list to store quotes
   
table = cuerpo.find('link', attrs = {'href':'all_quotes'})

# %%
table

# %%
for category in cuerpo.findAll("href"):
    print(category)

# %%
cuerpo.find("input data-ids-avisos-mostrados") #findAll("span")

# %%
cuerpo.findAll("div", {"class", ""})
# Out:
# [<div class="" data-checkbox-behavior="" data-filter-active-button="" id="tipooperacionContainer">
#  <div class="available__content" id="tipooperacionFilter">
#  <ul>
#  <li>
#  <label class="checkbox-styled">
#  <input checked="" data-filter-name="tipooperacion" data-filter-value="Venta" id="tipooperacion_venta" name="tipooperacion" type="checkbox" value="venta"/>
#  <span>
#                      Venta
#                  </span>
#  </label>
#  </li>
#  <li>
#  <label class="checkbox-styled">
#  <input data-filter-name="tipooperacion" data-filter-value="Alquiler" id="tipooperacion_alquiler" name="tipooperacion" type="checkbox" value="alquiler"/>
#  <span>
#                      Alquiler
#                  </span>
#  </label>
#  </li>
#  <li>
#  <label class="checkbox-styled">
#  <input data-filter-name="tipooperacion" data-filter-value="Alquiler Por Temporada" id="tipooperacion_alquiler-por-temporada" name="tipooperacion" type="checkbox" value="alquiler-por-temporada"/>
#  <span>
# ...

# %%
list_categories = []

for category in cuerpo:
    new_href = category.get("href")
    list_categories.append(new_href)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [17], line 4
#       1 list_categories = []
#       3 for category in cuerpo:
# ----> 4     new_href = category.get("href")
#       5     list_categories.append(new_href)
#
# File ~/.local/lib/python3.10/site-packages/bs4/element.py:965, in NavigableString.__getattr__(self, attr)
#     963     return self
#     964 else:
# --> 965     raise AttributeError(
#     966         "'%s' object has no attribute '%s'" % (
#     967             self.__class__.__name__, attr))
#
# AttributeError: 'Doctype' object has no attribute 'get'

# %%
list_categories
# Out:
# ['https://www.argenprop.com/Garantias-Alquiler?utm_source=argenprop&utm_medium=alertheader&utm_campaign=garantias_alquiler']

# %%
list_categories = []

for categories in categories_list:
        new_href = categories.get("href")
        new_href="https://www.argenprop.com"+new_href
        new_cat_title = categories.text.strip()
#         if new_herf != "None":
        list_categories.append([new_href,new_cat_title])
    
list_categories = pd.DataFrame(list_categories,columns = ['url','category'])

# %%
list_categories
# Out:
#                                                  url  \
# 0  https://www.argenprop.comhttps://www.argenprop...
#
#                     category
# 0  Cotizá gratis tu Garantía

# %%
url = "http://www.hubertiming.com/results/2017GPTR10K"
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
bs4.BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 bs4.BeautifulSoup
#
# NameError: name 'bs4' is not defined

# %%
title = soup.title
print(title)
# Out:
# <title>Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!</title>
